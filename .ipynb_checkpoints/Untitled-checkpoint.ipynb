# %%
# !pip install pandas
# !pip install numpy
# !pip install xgboost=1.6.1
# !pip install scikit-learn
# !pip install seaborn
# !pip install matplotlib
# !pip install catboost
# !pip install shap

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import xgboost as xgb
import catboost
import shap
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, f1_score, recall_score
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Import and Visualize dataset:
# - Number rows and columns
# - Look at a dataset sample
# - Calculate the balance between 'good' and 'bad'

# %%
df = pd.read_csv('credit-g.csv')
print('shape: ',df.shape)
print(df.head())
print('columns: ',df.columns)
# Out:
# shape:  (1000, 21)
#   checking_status  duration                  credit_history  \
# 0              <0         6  critical/other existing credit
# 1        0<=X<200        48                   existing paid
# 2     no checking        12  critical/other existing credit
# 3              <0        42                   existing paid
# 4              <0        24              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv           1169  no known savings        >=7
# 1             radio/tv           5951              <100     1<=X<4
# 2            education           2096              <100     4<=X<7
# 3  furniture/equipment           7882              <100     4<=X<7
# 4              new car           4870              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  ...  \
# 0                       4         male single          none  ...
# 1                       2  female div/dep/mar          none  ...
# 2                       2         male single          none  ...
# 3                       2         male single     guarantor  ...
# 4                       3         male single          none  ...
#
#    property_magnitude age   other_payment_plans   housing existing_credits  \
# 0         real estate  67                  none       own                2
# 1         real estate  22                  none       own                1
# 2         real estate  49                  none       own                1
# 3      life insurance  45                  none  for free                1
# 4   no known property  53                  none  for free                2
#
#                   job num_dependents  own_telephone  foreign_worker class
# 0             skilled              1            yes             yes  good
# 1             skilled              1           none             yes   bad
# 2  unskilled resident              2           none             yes  good
# 3             skilled              2           none             yes  good
# 4             skilled              2           none             yes   bad
#
# [5 rows x 21 columns]
# columns:  Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', ' other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        ' foreign_worker', 'class'],
#       dtype='object')

# %%
df.groupby('class').agg({'class': len})
# Out:
#        class
# class
# bad      300
# good     700

# %% [markdown]
# Notes:
# - 7 features are numerical, the other ones are categorical
# - bad customers make up 30% of the dataset or a 43% ratio

# %% [markdown]
# ### Data Preparation
# - Look for any missing values
# - Examine data types for all columns

# %%
# NaN
print(df.isnull().any())
# Types
print(df.dtypes)
# Out:
# checking_status           False
# duration                  False
# credit_history            False
# purpose                   False
# credit_amount             False
# savings_status            False
# employment                False
# installment_commitment    False
# personal_status           False
# other_parties             False
# residence_since           False
# property_magnitude        False
# age                       False
#  other_payment_plans      False
# housing                   False
# existing_credits          False
# job                       False
# num_dependents            False
# own_telephone             False
#  foreign_worker           False
# class                     False
# dtype: bool
# checking_status           object
# duration                   int64
# credit_history            object
# purpose                   object
# credit_amount              int64
# savings_status            object
# employment                object
# installment_commitment     int64
# personal_status           object
# other_parties             object
# residence_since            int64
# property_magnitude        object
# age                        int64
#  other_payment_plans      object
# housing                   object
# existing_credits           int64
# job                       object
# num_dependents             int64
# own_telephone             object
#  foreign_worker           object
# class                     object
# dtype: object

# %% [markdown]
# ### Data Exploration
# - Split the dataset between numerical and categorical features to look at those separately
# - Create numerical classes for easier exploration
# - Visualize correlation using Pearson Correlations
# - Visualize distributions of classes by feature to gauge potential correlations with good/bad ratings

# %%
numerical_feats = ['duration','credit_amount', 'installment_commitment', \
       'residence_since', 'age', 'existing_credits', 'num_dependents']
cat_feats = [x for x in df.columns if x not in numerical_feats][:-1]

# %%
# Create numerical classes for easier exploration
print(df['class'].unique())
df['class_num'] = df['class'].apply(lambda x: 1 if x == 'good' else 0)
# Out:
# ['good' 'bad']

# %%
# Pearson correlation matrix
df_num = df[numerical_feats+['class_num']]
sns.heatmap(df_num.corr(), cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### Numerical Features:
# - Let's visualize numerical features first
# -

# %%
def numeric_desc(col):
    tmp = df[[col, 'class']]
    
    class_averages = tmp.groupby(['class']).agg({col: np.mean})
    good, bad = class_averages.loc['good'][0], class_averages.loc['bad'][0]
    print(class_averages)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4))
    fig.suptitle(col)
    ax1.bar(['Good', 'Bad'],[good, bad], color = ['#094D92','#C3F73A'], alpha = 1)
    ax1.set_title('Average Value')
    ax2.hist(df_num[df_num['class_num'] == 1][col], density = True, color = '#094D92')
    ax2.hist(df_num[df_num['class_num'] == 0][col], density = True, color = '#C3F73A', alpha = 0.8)
    ax2.set_title('Value Distribution')
    plt.legend(['Good', 'Bad'])
    plt.show()

for feat in numerical_feats:
    numeric_desc(feat)
# Out:
#         duration
# class
# bad    24.860000
# good   19.207143
#        credit_amount
# class
# bad      3938.126667
# good     2985.457143
#        installment_commitment
# class
# bad                  3.096667
# good                 2.920000
#        residence_since
# class
# bad           2.850000
# good          2.842857
#              age
# class
# bad    33.963333
# good   36.224286
#        existing_credits
# class
# bad            1.366667
# good           1.424286
#        num_dependents
# class
# bad          1.153333
# good         1.155714

# %%
#Feature differentiation:
def num_feature_differentiation(feat):
    subset = df[[feat, 'class']]
    avg_class_value = subset.groupby('class').agg({feat: np.mean}).sort_values(feat, ascending=False)
    max_val, min_val = max(avg_class_value[feat]), min(avg_class_value[feat])
    
    diff = (max_val-min_val) / min_val
    return feat, diff

num_feature_differentiation_df = pd.DataFrame(columns = ['Feature', '% Value Difference btw good and bad'])

for i, feature in enumerate(numerical_feats):
    num_feature_differentiation_df.loc[i] = num_feature_differentiation(feature)

num_feature_differentiation_df.sort_values('% Value Difference btw good and bad', ascending=False, inplace=True)    
num_feature_differentiation_df
# Out:
#                   Feature  % Value Difference btw good and bad
# 1           credit_amount                             0.319103
# 0                duration                             0.294310
# 4                     age                             0.066570
# 2  installment_commitment                             0.060502
# 5        existing_credits                             0.042160
# 3         residence_since                             0.002513
# 6          num_dependents                             0.002064

# %%
score_mean = df['class_num'].mean()

def cat_cols(col):
    tmp = df[[col, 'class_num']]
    scores = tmp.groupby([col]).agg({'class_num': np.mean})
    scores.sort_values('class_num',inplace=True, ascending=False)
    sns.barplot(data=scores, x=scores.index, y='class_num', color='#094D92')
    plt.axhline(score_mean, color = '#C3F73A', linestyle='--')
    plt.xticks(rotation=90)
    plt.title(f'{col}')
    plt.show()
    
for feat in cat_feats:
    cat_cols(feat)

# %% [markdown]
# ### Identify the three most significant data features which drive the credit risk

# %%
# Features with biggest separation between high and low:

def feature_differentiation(feat):
    subset = df[[feat, 'class_num']]
    avg_category_value = subset.groupby([feat]).agg({'class_num': np.mean}).sort_values('class_num', ascending=False)
    max_val, max_cat = avg_category_value['class_num'][0], avg_category_value.index[0]
    min_val, min_cat = avg_category_value['class_num'][-1], avg_category_value.index[-1]
    
    diff = (max_val-min_val) / min_val
    return feat, max_cat, min_val, diff

feature_differentiation_df = pd.DataFrame(columns = ['Feature', 'Max Category', 'Min Category', '% Difference'])

for i, feature in enumerate(cat_feats):
    feature_differentiation_df.loc[i] = feature_differentiation(feature)

feature_differentiation_df.sort_values('% Difference', ascending=False, inplace=True)    
feature_differentiation_df
# Out:
#                  Feature                    Max Category  Min Category  \
# 1         credit_history  critical/other existing credit      0.375000
# 0        checking_status                     no checking      0.507299
# 2                purpose                      retraining      0.560000
# 6          other_parties                       guarantor      0.560976
# 7     property_magnitude                     real estate      0.564935
# 3         savings_status                          >=1000      0.640133
# 4             employment                          4<=X<7      0.593023
# 12        foreign_worker                              no      0.692627
# 9                housing                             own      0.592593
# 8    other_payment_plans                            none      0.589928
# 5        personal_status                     male single      0.600000
# 10                   job              unskilled resident      0.655405
# 11         own_telephone                             yes      0.686242
#
#     % Difference
# 1       1.211604
# 0       0.741080
# 2       0.587302
# 6       0.439799
# 7       0.393495
# 3       0.366904
# 4       0.308316
# 12      0.287694
# 9       0.247283
# 8       0.228651
# 5       0.222628
# 10      0.098557
# 11      0.049626

# %% [markdown]
# ### Modeling the credit risk

# %% [markdown]
# Create the dataset for the model:
# - One-hot encode Categorical Variables
# - Remove characters not supported by the model
# - Create a training and a testing set

# %%
#One-hot encoding:
X = pd.get_dummies(df[df.columns[:-2]])

#Replace characters that cause problem:
for i,a in enumerate(X.columns):
    b = a.replace('>',')')
    b = b.replace('<','(')
    X.rename({a: b}, inplace=True, axis = 1)

y = df['class_num']

#Create train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# -> One-hot encoding creates 60 total features, which is high for a dataset of 1000 observations, so we'll look at feature importance to try and select only the more important features

# %% [markdown]
# ### Model:
# - Build model with standard parameters
# - Using 43% imbalance ratio as starting point
# - Look at performance metrics in the classification report
# - The model does well identifying good ratings: in practice, you'd want to optimize for the 0 class, to find potential bad creditors

# %%
clf = xgb.XGBClassifier(
    learning_rate = 0.1, 
    n_estimators = 100,
    max_depth=3,
    scale_pos_weight=0.43,
    use_label_encoder=False 
)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(accuracy_score(y_test,y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.73
#               precision    recall  f1-score   support
#
#            0       0.53      0.67      0.59        58
#            1       0.85      0.75      0.80       142
#
#     accuracy                           0.73       200
#    macro avg       0.69      0.71      0.69       200
# weighted avg       0.76      0.73      0.74       200

# %% [markdown]
# -> By Tuning the model, we want to optimize the 0 recall and the 0 f1-score
# ### Feature Importance - using xgboost's built-in methodology:

# %%
print('Feature Importances from the model')
feature_importances_df = pd.DataFrame()
feature_importances_df['features'], feature_importances_df['importance'] = X_train.columns, clf.feature_importances_
feature_importances_df.sort_values('importance', ascending=True, inplace=True)
fig,ax = plt.subplots(figsize=(12,10))
plt.barh(feature_importances_df['features'][0:],feature_importances_df['importance'][0:])
plt.title('Feature Importance')
plt.show()
# Out:
# Feature Importances from the model

# %% [markdown]
# -> It looks like importance is dropping significantly towards the end: we should be able to remove some features

# %% [markdown]
# ### Feature Importance - using Shapley Values:

# %%
print('Feature Importances using Shapley Values')
explainer = shap.Explainer(clf)
shap_values = explainer(X_train)
X_test_array = np.array(X_train)
shap.summary_plot(shap_values, X_test_array, feature_names=X.columns, plot_size=(12,15), color_bar=False, max_display=X.shape[1])
plt.show()
# Out:
# Feature Importances using Shapley Values
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
vals = np.abs(shap_values.values).mean(0)
feature_names = X.columns
feature_importance = pd.DataFrame(list(zip(feature_names, vals)), columns=['col_name','feature_importance_vals'])
feature_importance.sort_values(by=['feature_importance_vals'], ascending=False, inplace=True)
feature_importance.tail(30)
# Out:
#                                 col_name  feature_importance_vals
# 39           personal_status_male single                 0.016453
# 36    personal_status_female div/dep/mar                 0.015834
# 37          personal_status_male div/sep                 0.015656
# 43                property_magnitude_car                 0.013085
# 45  property_magnitude_no known property                 0.012880
# 51                           housing_own                 0.012762
# 53         job_high qualif/self emp/mgmt                 0.012400
# 7               checking_status_0(=X(200                 0.010343
# 44     property_magnitude_life insurance                 0.006100
# 50                      housing_for free                 0.005191
# 14          credit_history_existing paid                 0.005039
# 34                        employment_)=7                 0.004687
# 26             savings_status_100(=X(500                 0.004583
# 49            other_payment_plans_stores                 0.003928
# 19           purpose_furniture/equipment                 0.002544
# 56                job_unskilled resident                 0.000000
# 58                     own_telephone_yes                 0.000000
# 55           job_unemp/unskilled non res                 0.000000
# 35                 employment_unemployed                 0.000000
# 42                    other_parties_none                 0.000000
# 38          personal_status_male mar/wid                 0.000000
# 29                 savings_status_)=1000                 0.000000
# 27            savings_status_500(=X(1000                 0.000000
# 24                    purpose_retraining                 0.000000
# 23                       purpose_repairs                 0.000000
# 21                         purpose_other                 0.000000
# 17            purpose_domestic appliance                 0.000000
# 16                      purpose_business                 0.000000
# 13     credit_history_delayed previously                 0.000000
# 60                    foreign_worker_yes                 0.000000

# %% [markdown]
# ### Feature Selection:
# - Using both methodologies

# %% [markdown]
# Validation - Tuning
# - We'll try combinations of parameters and look for high recall and goo F1 Score

# %%
learning_rate_list = [0.01,0.05,0,1,0.15,0.2]
n_estimator_list = [50,100,200,300]
scale_pos_weight_list = [0.25,0.45,0.6,1]
max_depth_list = [2,3,6,8,10]

X_train_, X_val, y_train_, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 1)

def run_model(param_list):
    lr, ne, sp, md = param_list
    clf = xgb.XGBClassifier(
    learning_rate = lr, 
    n_estimators = ne,
    max_depth = md,
    scale_pos_weight=sp,
    use_label_encoder=False,
    verbosity = 0
    )

    clf.fit(X_train_, y_train_)
    y_pred = clf.predict(X_val)
    
    recall, f1 = recall_score(y_val, y_pred, pos_label=1), f1_score(y_val, y_pred, pos_label=1)
    neg_recall, neg_f1 = recall_score(y_val, y_pred, pos_label=0), f1_score(y_val, y_pred, pos_label=0)
    
    return recall, f1, neg_recall, neg_f1, sum(y_pred)/len(y_pred), (len(y_pred) - sum(y_pred))/len(y_pred)

grid = [[a,b,c,d] for a in learning_rate_list for b in n_estimator_list for c in scale_pos_weight_list for d in max_depth_list]  
val_df = pd.DataFrame(columns = ['params', 'neg_recall', 'neg_f1_score', 'recall', 'f1_score', '%Positive Predictions', '%Negative Predictions'])

for i,tup in enumerate(grid):
    recall, f1, neg_recall, neg_f1, pos_pred, neg_pred = run_model(tup)
    val_df.loc[i] = [tup, recall, f1, neg_recall, neg_f1, pos_pred, neg_pred]

val_df.sort_values('neg_recall', ascending=False, inplace = True)

print(val_df.head(50))
# Out:
#                  params  neg_recall  neg_f1_score    recall  f1_score  \
# 15     [0.01, 50, 1, 2]    0.982906      0.861423  0.186047  0.301887
# 35    [0.01, 100, 1, 2]    0.982906      0.861423  0.186047  0.301887
# 95     [0.05, 50, 1, 2]    0.974359      0.890625  0.418605  0.562500
# 75    [0.01, 300, 1, 2]    0.974359      0.890625  0.418605  0.562500
# 55    [0.01, 200, 1, 2]    0.974359      0.887160  0.395349  0.539683
# 115   [0.05, 100, 1, 2]    0.948718      0.874016  0.395349  0.515152
# 335    [0.15, 50, 1, 2]    0.940171      0.883534  0.488372  0.591549
# 96     [0.05, 50, 1, 3]    0.931624      0.868526  0.418605  0.521739
# 415     [0.2, 50, 1, 2]    0.923077      0.874494  0.488372  0.575342
# 56    [0.01, 200, 1, 3]    0.923077      0.857143  0.372093  0.470588
# 76    [0.01, 300, 1, 3]    0.923077      0.860558  0.395349  0.492754
# 36    [0.01, 100, 1, 3]    0.914530      0.852590  0.372093  0.463768
# 116   [0.05, 100, 1, 3]    0.914530      0.873469  0.511628  0.586667
# 17     [0.01, 50, 1, 6]    0.905983      0.868852  0.511628  0.578947
# 135   [0.05, 200, 1, 2]    0.905983      0.858300  0.441860  0.520548
# 419    [0.2, 50, 1, 10]    0.897436      0.882353  0.627907  0.658537
# 16     [0.01, 50, 1, 3]    0.897436      0.836653  0.325581  0.405797
# 136   [0.05, 200, 1, 3]    0.888889      0.866667  0.558140  0.600000
# 97     [0.05, 50, 1, 6]    0.888889      0.866667  0.558140  0.600000
# 37    [0.01, 100, 1, 6]    0.888889      0.870293  0.581395  0.617284
# 78    [0.01, 300, 1, 8]    0.888889      0.873950  0.604651  0.634146
# 479   [0.2, 300, 1, 10]    0.888889      0.870293  0.581395  0.617284
# 155   [0.05, 300, 1, 2]    0.888889      0.863071  0.534884  0.582278
# 258       [1, 50, 1, 8]    0.880342      0.858333  0.534884  0.575000
# 117   [0.05, 100, 1, 6]    0.880342      0.865546  0.581395  0.609756
# 336    [0.15, 50, 1, 3]    0.880342      0.858333  0.534884  0.575000
# 57    [0.01, 200, 1, 6]    0.880342      0.861925  0.558140  0.592593
# 435    [0.2, 100, 1, 2]    0.880342      0.861925  0.558140  0.592593
# 77    [0.01, 300, 1, 6]    0.880342      0.865546  0.581395  0.609756
# 358   [0.15, 100, 1, 8]    0.880342      0.872881  0.627907  0.642857
# 436    [0.2, 100, 1, 3]    0.880342      0.858333  0.534884  0.575000
# 338    [0.15, 50, 1, 8]    0.871795      0.868085  0.627907  0.635294
# 477    [0.2, 300, 1, 6]    0.871795      0.864407  0.604651  0.619048
# 118   [0.05, 100, 1, 8]    0.871795      0.853556  0.534884  0.567901
# 58    [0.01, 200, 1, 8]    0.871795      0.860759  0.581395  0.602410
# 98     [0.05, 50, 1, 8]    0.871795      0.857143  0.558140  0.585366
# 156   [0.05, 300, 1, 3]    0.871795      0.864407  0.604651  0.619048
# 455    [0.2, 200, 1, 2]    0.871795      0.857143  0.558140  0.585366
# 278      [1, 100, 1, 8]    0.863248      0.848739  0.534884  0.560976
# 138   [0.05, 200, 1, 8]    0.863248      0.855932  0.581395  0.595238
# 355   [0.15, 100, 1, 2]    0.863248      0.845188  0.511628  0.543210
# 437    [0.2, 100, 1, 6]    0.863248      0.863248  0.627907  0.627907
# 379  [0.15, 200, 1, 10]    0.863248      0.859574  0.604651  0.611765
# 416     [0.2, 50, 1, 3]    0.863248      0.852321  0.558140  0.578313
# 158   [0.05, 300, 1, 8]    0.863248      0.848739  0.534884  0.560976
# 439   [0.2, 100, 1, 10]    0.863248      0.863248  0.627907  0.627907
# 417     [0.2, 50, 1, 6]    0.863248      0.859574  0.604651  0.611765
# 38    [0.01, 100, 1, 8]    0.863248      0.855932  0.581395  0.595238
# 457    [0.2, 200, 1, 6]    0.863248      0.863248  0.627907  0.627907
# 475    [0.2, 300, 1, 2]    0.863248      0.855932  0.581395  0.595238
#
#      %Positive Predictions  %Negative Predictions
# 15                 0.93750                0.06250
# 35                 0.93750                0.06250
# 95                 0.86875                0.13125
# 75                 0.86875                0.13125
# 55                 0.87500                0.12500
# 115                0.85625                0.14375
# 335                0.82500                0.17500
# 96                 0.83750                0.16250
# 415                0.81250                0.18750
# 56                 0.84375                0.15625
# 76                 0.83750                0.16250
# 36                 0.83750                0.16250
# 116                0.80000                0.20000
# 17                 0.79375                0.20625
# 135                0.81250                0.18750
# 419                0.75625                0.24375
# 16                 0.83750                0.16250
# 136                0.76875                0.23125
# 97                 0.76875                0.23125
# 37                 0.76250                0.23750
# 78                 0.75625                0.24375
# 479                0.76250                0.23750
# 155                0.77500                0.22500
# 258                0.76875                0.23125
# 117                0.75625                0.24375
# 336                0.76875                0.23125
# 57                 0.76250                0.23750
# 435                0.76250                0.23750
# 77                 0.75625                0.24375
# 358                0.74375                0.25625
# 436                0.76875                0.23125
# 338                0.73750                0.26250
# 477                0.74375                0.25625
# 118                0.76250                0.23750
# 58                 0.75000                0.25000
# 98                 0.75625                0.24375
# 156                0.74375                0.25625
# 455                0.75625                0.24375
# 278                0.75625                0.24375
# 138                0.74375                0.25625
# 355                0.76250                0.23750
# 437                0.73125                0.26875
# 379                0.73750                0.26250
# 416                0.75000                0.25000
# 158                0.75625                0.24375
# 439                0.73125                0.26875
# 417                0.73750                0.26250
# 38                 0.74375                0.25625
# 457                0.73125                0.26875
# 475                0.74375                0.25625

# %%
# Out:
# Feature Importances from the model

# %%
print('Feature Importances using Shapley Values')
explainer = shap.Explainer(clf)
shap_values = explainer(X_train)
X_test_array = np.array(X_train)
shap.summary_plot(shap_values, X_test_array, feature_names=X.columns, plot_size=(12,15), color_bar=False, max_display=X.shape[1])
plt.show()
# Out:
# Feature Importances using Shapley Values
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ### Model validation and evaluation using the methods that you find correct for the problem

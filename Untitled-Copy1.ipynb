# %%
# !pip install pandas
# !pip install numpy
# !pip install xgboost=1.6.1
# !pip install scikit-learn
# !pip install seaborn
# !pip install matplotlib
# !pip install catboost
# !pip install shap

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import xgboost as xgb
import catboost
import shap
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, f1_score, recall_score
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Import and Visualize dataset:
# - Number rows and columns
# - Look at a dataset sample
# - Calculate the balance between 'good' and 'bad'

# %%
df = pd.read_csv('credit-g.csv')
print('shape: ',df.shape)
print(df.head())
print('columns: ',df.columns)
# Out:
# shape:  (1000, 21)
#   checking_status  duration                  credit_history  \
# 0              <0         6  critical/other existing credit
# 1        0<=X<200        48                   existing paid
# 2     no checking        12  critical/other existing credit
# 3              <0        42                   existing paid
# 4              <0        24              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv           1169  no known savings        >=7
# 1             radio/tv           5951              <100     1<=X<4
# 2            education           2096              <100     4<=X<7
# 3  furniture/equipment           7882              <100     4<=X<7
# 4              new car           4870              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  ...  \
# 0                       4         male single          none  ...
# 1                       2  female div/dep/mar          none  ...
# 2                       2         male single          none  ...
# 3                       2         male single     guarantor  ...
# 4                       3         male single          none  ...
#
#    property_magnitude age   other_payment_plans   housing existing_credits  \
# 0         real estate  67                  none       own                2
# 1         real estate  22                  none       own                1
# 2         real estate  49                  none       own                1
# 3      life insurance  45                  none  for free                1
# 4   no known property  53                  none  for free                2
#
#                   job num_dependents  own_telephone  foreign_worker class
# 0             skilled              1            yes             yes  good
# 1             skilled              1           none             yes   bad
# 2  unskilled resident              2           none             yes  good
# 3             skilled              2           none             yes  good
# 4             skilled              2           none             yes   bad
#
# [5 rows x 21 columns]
# columns:  Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', ' other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        ' foreign_worker', 'class'],
#       dtype='object')

# %%
df.groupby('class').agg({'class': len})
# Out:
#        class
# class
# bad      300
# good     700

# %% [markdown]
# Notes:
# - 7 features are numerical, the other ones are categorical
# - bad customers make up 30% of the dataset or a 43% ratio

# %% [markdown]
# ### Data Preparation
# - Look for any missing values
# - Examine data types for all columns

# %%
# NaN
print(df.isnull().any())
# Types
print(df.dtypes)
# Out:
# checking_status           False
# duration                  False
# credit_history            False
# purpose                   False
# credit_amount             False
# savings_status            False
# employment                False
# installment_commitment    False
# personal_status           False
# other_parties             False
# residence_since           False
# property_magnitude        False
# age                       False
#  other_payment_plans      False
# housing                   False
# existing_credits          False
# job                       False
# num_dependents            False
# own_telephone             False
#  foreign_worker           False
# class                     False
# dtype: bool
# checking_status           object
# duration                   int64
# credit_history            object
# purpose                   object
# credit_amount              int64
# savings_status            object
# employment                object
# installment_commitment     int64
# personal_status           object
# other_parties             object
# residence_since            int64
# property_magnitude        object
# age                        int64
#  other_payment_plans      object
# housing                   object
# existing_credits           int64
# job                       object
# num_dependents             int64
# own_telephone             object
#  foreign_worker           object
# class                     object
# dtype: object

# %% [markdown]
# ### Data Exploration
# - Split the dataset between numerical and categorical features to look at those separately
# - Create numerical classes for easier exploration
# - Visualize correlation using Pearson Correlations
# - Visualize distributions of classes by feature to gauge potential correlations with good/bad ratings

# %%
numerical_feats = ['duration','credit_amount', 'installment_commitment', \
       'residence_since', 'age', 'existing_credits', 'num_dependents']
cat_feats = [x for x in df.columns if x not in numerical_feats][:-1]

# %%
# Create numerical classes for easier exploration
print(df['class'].unique())
df['class_num'] = df['class'].apply(lambda x: 1 if x == 'good' else 0)
# Out:
# ['good' 'bad']

# %%
# Pearson correlation matrix
df_num = df[numerical_feats+['class_num']]
sns.heatmap(df_num.corr(), cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### Numerical Features:
# - Let's visualize numerical features first
# -

# %%
def numeric_desc(col):
    tmp = df[[col, 'class']]
    
    class_averages = tmp.groupby(['class']).agg({col: np.mean})
    good, bad = class_averages.loc['good'][0], class_averages.loc['bad'][0]
    print(class_averages)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,4))
    fig.suptitle(col)
    ax1.bar(['Good', 'Bad'],[good, bad], color = ['#094D92','#C3F73A'], alpha = 1)
    ax1.set_title('Average Value')
    ax2.hist(df_num[df_num['class_num'] == 1][col], density = True, color = '#094D92')
    ax2.hist(df_num[df_num['class_num'] == 0][col], density = True, color = '#C3F73A', alpha = 0.8)
    ax2.set_title('Value Distribution')
    plt.legend(['Good', 'Bad'])
    plt.show()

for feat in numerical_feats:
    numeric_desc(feat)
# Out:
#         duration
# class
# bad    24.860000
# good   19.207143
#        credit_amount
# class
# bad      3938.126667
# good     2985.457143
#        installment_commitment
# class
# bad                  3.096667
# good                 2.920000
#        residence_since
# class
# bad           2.850000
# good          2.842857
#              age
# class
# bad    33.963333
# good   36.224286
#        existing_credits
# class
# bad            1.366667
# good           1.424286
#        num_dependents
# class
# bad          1.153333
# good         1.155714

# %%
#Feature differentiation:
def num_feature_differentiation(feat):
    subset = df[[feat, 'class']]
    avg_class_value = subset.groupby('class').agg({feat: np.mean}).sort_values(feat, ascending=False)
    max_val, min_val = max(avg_class_value[feat]), min(avg_class_value[feat])
    
    diff = (max_val-min_val) / min_val
    return feat, diff

num_feature_differentiation_df = pd.DataFrame(columns = ['Feature', '% Value Difference btw good and bad'])

for i, feature in enumerate(numerical_feats):
    num_feature_differentiation_df.loc[i] = num_feature_differentiation(feature)

num_feature_differentiation_df.sort_values('% Value Difference btw good and bad', ascending=False, inplace=True)    
num_feature_differentiation_df
# Out:
#                   Feature  % Value Difference btw good and bad
# 1           credit_amount                             0.319103
# 0                duration                             0.294310
# 4                     age                             0.066570
# 2  installment_commitment                             0.060502
# 5        existing_credits                             0.042160
# 3         residence_since                             0.002513
# 6          num_dependents                             0.002064

# %%
score_mean = df['class_num'].mean()

def cat_cols(col):
    tmp = df[[col, 'class_num']]
    scores = tmp.groupby([col]).agg({'class_num': np.mean})
    scores.sort_values('class_num',inplace=True, ascending=False)
    sns.barplot(data=scores, x=scores.index, y='class_num', color='#094D92')
    plt.axhline(score_mean, color = '#C3F73A', linestyle='--')
    plt.xticks(rotation=90)
    plt.title(f'{col}')
    plt.show()
    
for feat in cat_feats:
    cat_cols(feat)

# %% [markdown]
# ### Identify the three most significant data features which drive the credit risk

# %%
# Features with biggest separation between high and low:

def feature_differentiation(feat):
    subset = df[[feat, 'class_num']]
    avg_category_value = subset.groupby([feat]).agg({'class_num': np.mean}).sort_values('class_num', ascending=False)
    max_val, max_cat = avg_category_value['class_num'][0], avg_category_value.index[0]
    min_val, min_cat = avg_category_value['class_num'][-1], avg_category_value.index[-1]
    
    diff = (max_val-min_val) / min_val
    return feat, max_cat, min_val, diff

feature_differentiation_df = pd.DataFrame(columns = ['Feature', 'Max Category', 'Min Category', '% Difference'])

for i, feature in enumerate(cat_feats):
    feature_differentiation_df.loc[i] = feature_differentiation(feature)

feature_differentiation_df.sort_values('% Difference', ascending=False, inplace=True)    
feature_differentiation_df
# Out:
#                  Feature                    Max Category  Min Category  \
# 1         credit_history  critical/other existing credit      0.375000
# 0        checking_status                     no checking      0.507299
# 2                purpose                      retraining      0.560000
# 6          other_parties                       guarantor      0.560976
# 7     property_magnitude                     real estate      0.564935
# 3         savings_status                          >=1000      0.640133
# 4             employment                          4<=X<7      0.593023
# 12        foreign_worker                              no      0.692627
# 9                housing                             own      0.592593
# 8    other_payment_plans                            none      0.589928
# 5        personal_status                     male single      0.600000
# 10                   job              unskilled resident      0.655405
# 11         own_telephone                             yes      0.686242
#
#     % Difference
# 1       1.211604
# 0       0.741080
# 2       0.587302
# 6       0.439799
# 7       0.393495
# 3       0.366904
# 4       0.308316
# 12      0.287694
# 9       0.247283
# 8       0.228651
# 5       0.222628
# 10      0.098557
# 11      0.049626

# %% [markdown]
# ### Modeling the credit risk

# %% [markdown]
# Create the dataset for the model:
# - One-hot encode Categorical Variables
# - Remove characters not supported by the model
# - Create a training and a testing set

# %%
#One-hot encoding:
X = pd.get_dummies(df[df.columns[:-2]])

#Replace characters that cause problem:
for i,a in enumerate(X.columns):
    b = a.replace('>',')')
    b = b.replace('<','(')
    X.rename({a: b}, inplace=True, axis = 1)

y = df['class_num']

#Create train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=43)

# %% [markdown]
# -> One-hot encoding creates 60 total features, which is high for a dataset of 1000 observations, so we'll look at feature importance to try and select only the more important features

# %% [markdown]
# ### Model:
# - Build model with standard parameters
# - Using 43% imbalance ratio as starting point
# - Look at performance metrics in the classification report
# - The model does well identifying good ratings: in practice, you'd want to optimize for the 0 class, to find potential bad creditors

# %%
clf = xgb.XGBClassifier(
    learning_rate = 0.1, 
    n_estimators = 100,
    max_depth=3,
    scale_pos_weight=0.43,
    use_label_encoder=False 
)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.54      0.51        65
#            1       0.76      0.72      0.74       135
#
#     accuracy                           0.66       200
#    macro avg       0.62      0.63      0.62       200
# weighted avg       0.67      0.66      0.66       200

# %% [markdown]
# -> By Tuning the model, we want to optimize the 0 recall and the 0 f1-score
# ### Feature Importance - using xgboost's built-in methodology:

# %%
print('Feature Importances from the model')
feature_importances_df = pd.DataFrame()
feature_importances_df['features'], feature_importances_df['importance'] = X_train.columns, clf.feature_importances_
feature_importances_df.sort_values('importance', ascending=True, inplace=True)
fig,ax = plt.subplots(figsize=(12,10))
plt.barh(feature_importances_df['features'][0:],feature_importances_df['importance'][0:])
plt.title('Feature Importance')
plt.show()
# Out:
# Feature Importances from the model

# %% [markdown]
# -> It looks like importance is dropping significantly towards the end: we should be able to remove some features

# %% [markdown]
# ### Feature Importance - using Shapley Values:

# %%
print('Feature Importances using Shapley Values')
explainer = shap.Explainer(clf)
shap_values = explainer(X_train)
X_test_array = np.array(X_train)
shap.summary_plot(shap_values, X_test_array, feature_names=X.columns, plot_size=(12,15), color_bar=False, max_display=X.shape[1])
plt.show()
# Out:
# Feature Importances using Shapley Values
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
vals = np.abs(shap_values.values).mean(0)
feature_names = X.columns
feature_importance = pd.DataFrame(list(zip(feature_names, vals)), columns=['col_name','feature_importance_vals'])
feature_importance.sort_values(by=['feature_importance_vals'], ascending=False, inplace=True)
feature_importance.reset_index(drop=True, inplace=True)
feature_importance.head(20)
# Out:
#                                          col_name  feature_importance_vals
# 0                     checking_status_no checking                 0.581716
# 1                                        duration                 0.399920
# 2   credit_history_critical/other existing credit                 0.278266
# 3                                   credit_amount                 0.219747
# 4                               employment_4(=X(7                 0.200791
# 5                                             age                 0.166859
# 6                                 purpose_new car                 0.166394
# 7                              checking_status_(0                 0.162903
# 8                                purpose_used car                 0.153568
# 9                             savings_status_(100                 0.142466
# 10                       other_payment_plans_none                 0.139864
# 11                         installment_commitment                 0.087099
# 12                    personal_status_male single                 0.078516
# 13                        other_parties_guarantor                 0.071032
# 14                              purpose_education                 0.059126
# 15                 property_magnitude_real estate                 0.058028
# 16                          savings_status_)=1000                 0.055704
# 17                               purpose_radio/tv                 0.054658
# 18                               existing_credits                 0.052122
# 19                              foreign_worker_no                 0.051618

# %%
feature_importance.tail(41)
# Out:
#                                 col_name  feature_importance_vals
# 20                         employment_(1                 0.045760
# 21       savings_status_no known savings                 0.043198
# 22                 checking_status_)=200                 0.040659
# 23    credit_history_no credits/all paid                 0.036893
# 24                          housing_rent                 0.030348
# 25     property_magnitude_life insurance                 0.029669
# 26                           job_skilled                 0.028478
# 27                       residence_since                 0.028295
# 28         job_high qualif/self emp/mgmt                 0.027716
# 29                    own_telephone_none                 0.024785
# 30  property_magnitude_no known property                 0.023021
# 31               credit_history_all paid                 0.021010
# 32     credit_history_delayed previously                 0.020866
# 33           purpose_furniture/equipment                 0.019394
# 34                        employment_)=7                 0.016514
# 35    personal_status_female div/dep/mar                 0.014261
# 36                property_magnitude_car                 0.014225
# 37              other_payment_plans_bank                 0.014013
# 38              checking_status_0(=X(200                 0.009894
# 39                      housing_for free                 0.008653
# 40                job_unskilled resident                 0.006891
# 41            other_parties_co applicant                 0.006260
# 42                        num_dependents                 0.005630
# 43                     employment_1(=X(4                 0.003875
# 44             savings_status_100(=X(500                 0.002709
# 45            other_payment_plans_stores                 0.002696
# 46          credit_history_existing paid                 0.002629
# 47            savings_status_500(=X(1000                 0.002100
# 48                           housing_own                 0.001891
# 49          personal_status_male div/sep                 0.001501
# 50           job_unemp/unskilled non res                 0.000000
# 51                     own_telephone_yes                 0.000000
# 52                         purpose_other                 0.000000
# 53                    other_parties_none                 0.000000
# 54                       purpose_repairs                 0.000000
# 55          personal_status_male mar/wid                 0.000000
# 56                 employment_unemployed                 0.000000
# 57                      purpose_business                 0.000000
# 58            purpose_domestic appliance                 0.000000
# 59                    purpose_retraining                 0.000000
# 60                    foreign_worker_yes                 0.000000

# %% [markdown]
# ### Feature Selection:
# - Using both methodologies it looks like we can drop the last 20 features
# - With more time, I would want to test combinations of features to find the best one
# - In this case we'll try with the top 40 features

# %%
selected_features = list(feature_importance['col_name'][:16])
X_train, X_test = X_train[selected_features], X_test[selected_features]

# %% [markdown]
# ### Validation - Tuning
# - We'll try combinations of parameters and look for high recall (0 class) and good F1 Score (1 class)

# %%
learning_rate_list = [0.01,0,1,0.2]
n_estimator_list = [50,100,200]
scale_pos_weight_list = [0.3,0.45,0.6,1]
max_depth_list = [2,3,6,8]

def run_model(param_list):
    lr, ne, sp, md = param_list
    clf = xgb.XGBClassifier(
    learning_rate = lr, 
    n_estimators = ne,
    max_depth = md,
    scale_pos_weight=sp,
    use_label_encoder=False,
    verbosity = 0
    )
    
    kfold = KFold(4, shuffle = True, random_state = 42)
    feat_cols = X_train.columns
    df_kfold = X_train.copy()
    df_kfold['class'] = y_train

    recall_list = []
    f1_list = []
    neg_recall_list = []
    neg_f1_list = []

    for train, val in kfold.split(X_train, y_train):
        df_train_, df_val = df_kfold.iloc[train], df_kfold.iloc[val]
        X_train_, X_val = df_train_.loc[:,feat_cols], df_val.loc[:,feat_cols]
        y_train_, y_val = df_train_['class'], df_val['class']
        clf.fit(X_train_,y_train_)
        val_pred = clf.predict(X_val)
        recall_list.append(recall_score(y_val, val_pred))
        f1_list.append(f1_score(y_val, val_pred))
        neg_recall_list.append(recall_score(y_val, val_pred, pos_label=0))
        neg_f1_list.append(f1_score(y_val, val_pred, pos_label=0))
    
    recall, f1 = np.mean(recall_list), np.mean(f1_list)
    neg_recall, neg_f1 = np.mean(neg_recall_list), np.mean(neg_f1_list)
    return recall, f1, neg_recall, neg_f1

grid = [[a,b,c,d] for a in learning_rate_list for b in n_estimator_list for c in scale_pos_weight_list for d in max_depth_list]  
val_df = pd.DataFrame(columns = ['params', 'neg_recall', 'neg_f1_score', 'recall', 'f1_score'])

for i,tup in enumerate(grid):
    recall, f1, neg_recall, neg_f1 = run_model(tup)
    val_df.loc[i] = [tup, recall, f1, neg_recall, neg_f1]

val_df['compounded_score'] = val_df['neg_recall'] * val_df['f1_score']
val_df.sort_values('compounded_score', ascending=False, inplace = True)

print(val_df.head(10))
# Out:
#                   params  neg_recall  neg_f1_score    recall  f1_score  \
# 153    [0.2, 50, 0.6, 3]    0.820415      0.835308  0.660821  0.626249
# 152    [0.2, 50, 0.6, 2]    0.821555      0.832865  0.648801  0.618830
# 168   [0.2, 100, 0.6, 2]    0.808883      0.826276  0.649164  0.611337
# 156      [0.2, 50, 1, 2]    0.890942      0.843904  0.484670  0.547619
# 169   [0.2, 100, 0.6, 3]    0.813417      0.825028  0.627891  0.599009
# 157      [0.2, 50, 1, 3]    0.885061      0.841460  0.489414  0.548737
# 184   [0.2, 200, 0.6, 2]    0.809353      0.821275  0.622425  0.592317
# 172     [0.2, 100, 1, 2]    0.874503      0.836312  0.498226  0.545966
# 42   [0.01, 200, 0.6, 6]    0.802718      0.819080  0.634226  0.594503
# 159      [0.2, 50, 1, 8]    0.862547      0.834115  0.519118  0.552142
#
#      %Positive Predictions  %Negative Predictions  compounded_score
# 153                  0.635                  0.365          0.513784
# 152                  0.635                  0.365          0.508403
# 168                  0.635                  0.365          0.494500
# 156                  0.635                  0.365          0.487897
# 169                  0.635                  0.365          0.487244
# 157                  0.635                  0.365          0.485666
# 184                  0.635                  0.365          0.479394
# 172                  0.635                  0.365          0.477449
# 42                   0.635                  0.365          0.477219
# 159                  0.635                  0.365          0.476249

# %% [markdown]
# ### Run Model with the best Performance

# %%
final_clf = xgb.XGBClassifier(
    learning_rate = 0.2, 
    n_estimators = 50,
    max_depth=3,
    scale_pos_weight=0.6,
    use_label_encoder=False 
)

# X = X[selected_features]
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)


kfold = KFold(3, shuffle = True, random_state = 42)
feat_cols = X_train.columns
df_kfold = X_train.copy()
df_kfold['class'] = y_train

recall_list = []
f1_list = []
neg_recall_list = []
neg_f1_list = []

for train, val in kfold.split(X_train, y_train):
    df_train_, df_val = df_kfold.iloc[train], df_kfold.iloc[val]
    X_train_, X_val = df_train_.loc[:,feat_cols], df_val.loc[:,feat_cols]
    y_train_, y_val = df_train_['class'], df_val['class']
    final_clf.fit(X_train_,y_train_)
    val_pred = clf.predict(X_val)
    print(classification_report(y_val, val_pred))
    recall_list.append(recall_score(y_val, val_pred))
    f1_list.append(f1_score(y_val, val_pred))
    neg_recall_list.append(recall_score(y_val, val_pred, pos_label=0))
    neg_f1_list.append(f1_score(y_val, val_pred, pos_label=0))

recall, f1 = np.mean(recall_list), np.mean(f1_list)
neg_recall, neg_f1 = np.mean(neg_recall_list), np.mean(neg_f1_list)

print(neg_recall_list)
print(neg_f1_list)








# neg_recall, neg_f1 = recall_score(y_test, y_pred, pos_label=0), f1_score(y_test, y_pred, pos_label=0)

# print(neg_recall, neg_f1)

# # print('Feature Importances using Shapley Values')
# explainer = shap.Explainer(clf)
# shap_values = explainer(X_train)
# X_test_array = np.array(X_train)
# shap.summary_plot(shap_values, X_test_array, feature_names=X.columns, plot_size=(12,15), color_bar=False, max_display=X.shape[1])
# plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.81        92
#            1       0.95      0.81      0.87       175
#
#     accuracy                           0.85       267
#    macro avg       0.83      0.86      0.84       267
# weighted avg       0.87      0.85      0.85       267
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        70
#            1       0.97      0.79      0.87       197
#
#     accuracy                           0.83       267
#    macro avg       0.79      0.86      0.81       267
# weighted avg       0.88      0.83      0.84       267
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.77      0.63        73
#            1       0.90      0.75      0.82       193
#
#     accuracy                           0.76       266
#    macro avg       0.72      0.76      0.72       266
# weighted avg       0.80      0.76      0.77       266
#
# [0.9239130434782609, 0.9428571428571428, 0.7671232876712328]
# [0.8056872037914692, 0.7415730337078652, 0.632768361581921]

# %%
grid
# Out:
# [[0.01, 50, 0.3, 2],
#  [0.01, 50, 0.3, 3],
#  [0.01, 50, 0.3, 6],
#  [0.01, 50, 0.3, 8],
#  [0.01, 50, 0.45, 2],
#  [0.01, 50, 0.45, 3],
#  [0.01, 50, 0.45, 6],
#  [0.01, 50, 0.45, 8],
#  [0.01, 50, 0.6, 2],
#  [0.01, 50, 0.6, 3],
#  [0.01, 50, 0.6, 6],
#  [0.01, 50, 0.6, 8],
#  [0.01, 50, 1, 2],
#  [0.01, 50, 1, 3],
#  [0.01, 50, 1, 6],
#  [0.01, 50, 1, 8],
#  [0.01, 100, 0.3, 2],
#  [0.01, 100, 0.3, 3],
#  [0.01, 100, 0.3, 6],
#  [0.01, 100, 0.3, 8],
#  [0.01, 100, 0.45, 2],
#  [0.01, 100, 0.45, 3],
#  [0.01, 100, 0.45, 6],
#  [0.01, 100, 0.45, 8],
#  [0.01, 100, 0.6, 2],
#  [0.01, 100, 0.6, 3],
#  [0.01, 100, 0.6, 6],
#  [0.01, 100, 0.6, 8],
#  [0.01, 100, 1, 2],
#  [0.01, 100, 1, 3],
#  [0.01, 100, 1, 6],
#  [0.01, 100, 1, 8],
#  [0.01, 200, 0.3, 2],
#  [0.01, 200, 0.3, 3],
#  [0.01, 200, 0.3, 6],
#  [0.01, 200, 0.3, 8],
#  [0.01, 200, 0.45, 2],
#  [0.01, 200, 0.45, 3],
#  [0.01, 200, 0.45, 6],
#  [0.01, 200, 0.45, 8],
#  [0.01, 200, 0.6, 2],
#  [0.01, 200, 0.6, 3],
#  [0.01, 200, 0.6, 6],
#  [0.01, 200, 0.6, 8],
#  [0.01, 200, 1, 2],
#  [0.01, 200, 1, 3],
#  [0.01, 200, 1, 6],
#  [0.01, 200, 1, 8],
#  [0, 50, 0.3, 2],
#  [0, 50, 0.3, 3],
#  [0, 50, 0.3, 6],
#  [0, 50, 0.3, 8],
#  [0, 50, 0.45, 2],
#  [0, 50, 0.45, 3],
#  [0, 50, 0.45, 6],
#  [0, 50, 0.45, 8],
#  [0, 50, 0.6, 2],
#  [0, 50, 0.6, 3],
#  [0, 50, 0.6, 6],
#  [0, 50, 0.6, 8],
#  [0, 50, 1, 2],
#  [0, 50, 1, 3],
#  [0, 50, 1, 6],
#  [0, 50, 1, 8],
#  [0, 100, 0.3, 2],
#  [0, 100, 0.3, 3],
#  [0, 100, 0.3, 6],
#  [0, 100, 0.3, 8],
#  [0, 100, 0.45, 2],
#  [0, 100, 0.45, 3],
#  [0, 100, 0.45, 6],
#  [0, 100, 0.45, 8],
#  [0, 100, 0.6, 2],
#  [0, 100, 0.6, 3],
#  [0, 100, 0.6, 6],
#  [0, 100, 0.6, 8],
#  [0, 100, 1, 2],
#  [0, 100, 1, 3],
#  [0, 100, 1, 6],
#  [0, 100, 1, 8],
#  [0, 200, 0.3, 2],
#  [0, 200, 0.3, 3],
#  [0, 200, 0.3, 6],
#  [0, 200, 0.3, 8],
#  [0, 200, 0.45, 2],
#  [0, 200, 0.45, 3],
#  [0, 200, 0.45, 6],
#  [0, 200, 0.45, 8],
#  [0, 200, 0.6, 2],
#  [0, 200, 0.6, 3],
#  [0, 200, 0.6, 6],
#  [0, 200, 0.6, 8],
#  [0, 200, 1, 2],
#  [0, 200, 1, 3],
#  [0, 200, 1, 6],
#  [0, 200, 1, 8],
#  [1, 50, 0.3, 2],
#  [1, 50, 0.3, 3],
#  [1, 50, 0.3, 6],
#  [1, 50, 0.3, 8],
#  [1, 50, 0.45, 2],
#  [1, 50, 0.45, 3],
#  [1, 50, 0.45, 6],
#  [1, 50, 0.45, 8],
#  [1, 50, 0.6, 2],
#  [1, 50, 0.6, 3],
#  [1, 50, 0.6, 6],
#  [1, 50, 0.6, 8],
#  [1, 50, 1, 2],
#  [1, 50, 1, 3],
#  [1, 50, 1, 6],
#  [1, 50, 1, 8],
#  [1, 100, 0.3, 2],
#  [1, 100, 0.3, 3],
#  [1, 100, 0.3, 6],
#  [1, 100, 0.3, 8],
#  [1, 100, 0.45, 2],
#  [1, 100, 0.45, 3],
#  [1, 100, 0.45, 6],
#  [1, 100, 0.45, 8],
#  [1, 100, 0.6, 2],
#  [1, 100, 0.6, 3],
#  [1, 100, 0.6, 6],
#  [1, 100, 0.6, 8],
#  [1, 100, 1, 2],
#  [1, 100, 1, 3],
#  [1, 100, 1, 6],
#  [1, 100, 1, 8],
#  [1, 200, 0.3, 2],
#  [1, 200, 0.3, 3],
#  [1, 200, 0.3, 6],
#  [1, 200, 0.3, 8],
#  [1, 200, 0.45, 2],
#  [1, 200, 0.45, 3],
#  [1, 200, 0.45, 6],
#  [1, 200, 0.45, 8],
#  [1, 200, 0.6, 2],
#  [1, 200, 0.6, 3],
#  [1, 200, 0.6, 6],
#  [1, 200, 0.6, 8],
#  [1, 200, 1, 2],
#  [1, 200, 1, 3],
#  [1, 200, 1, 6],
#  [1, 200, 1, 8],
#  [0.2, 50, 0.3, 2],
#  [0.2, 50, 0.3, 3],
#  [0.2, 50, 0.3, 6],
#  [0.2, 50, 0.3, 8],
#  [0.2, 50, 0.45, 2],
#  [0.2, 50, 0.45, 3],
#  [0.2, 50, 0.45, 6],
#  [0.2, 50, 0.45, 8],
#  [0.2, 50, 0.6, 2],
#  [0.2, 50, 0.6, 3],
#  [0.2, 50, 0.6, 6],
#  [0.2, 50, 0.6, 8],
#  [0.2, 50, 1, 2],
#  [0.2, 50, 1, 3],
#  [0.2, 50, 1, 6],
#  [0.2, 50, 1, 8],
#  [0.2, 100, 0.3, 2],
#  [0.2, 100, 0.3, 3],
#  [0.2, 100, 0.3, 6],
#  [0.2, 100, 0.3, 8],
#  [0.2, 100, 0.45, 2],
#  [0.2, 100, 0.45, 3],
#  [0.2, 100, 0.45, 6],
#  [0.2, 100, 0.45, 8],
#  [0.2, 100, 0.6, 2],
#  [0.2, 100, 0.6, 3],
#  [0.2, 100, 0.6, 6],
#  [0.2, 100, 0.6, 8],
#  [0.2, 100, 1, 2],
#  [0.2, 100, 1, 3],
#  [0.2, 100, 1, 6],
#  [0.2, 100, 1, 8],
#  [0.2, 200, 0.3, 2],
#  [0.2, 200, 0.3, 3],
#  [0.2, 200, 0.3, 6],
#  [0.2, 200, 0.3, 8],
#  [0.2, 200, 0.45, 2],
#  [0.2, 200, 0.45, 3],
#  [0.2, 200, 0.45, 6],
#  [0.2, 200, 0.45, 8],
#  [0.2, 200, 0.6, 2],
#  [0.2, 200, 0.6, 3],
#  [0.2, 200, 0.6, 6],
#  [0.2, 200, 0.6, 8],
#  [0.2, 200, 1, 2],
#  [0.2, 200, 1, 3],
#  [0.2, 200, 1, 6],
#  [0.2, 200, 1, 8]]

# %% [markdown]
# ### Model validation and evaluation using the methods that you find correct for the problem
